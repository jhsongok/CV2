# %%
# 내 구글 드라이브 연동
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Colab에서 GitHub 에 있는 데이터 가져오기
# model 다운로드 URL : https://github.com/anishathalye/neural-style
# Clone Web URL 를 복사해 옵니다.

# !git clone https://github.com/anishathalye/neural-style.git
# Out:
# Cloning into 'neural-style'...
# remote: Enumerating objects: 325, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 325 (delta 1), reused 6 (delta 1), pack-reused 314
# Receiving objects: 100% (325/325), 2.65 MiB | 44.43 MiB/s, done.
# Resolving deltas: 100% (167/167), done.

# %%
# VGG19 모델을 내려받는다
# !wget https://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Out:
# --2021-05-11 02:20:36--  https://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Resolving www.vlfeat.org (www.vlfeat.org)... 64.90.48.57
# Connecting to www.vlfeat.org (www.vlfeat.org)|64.90.48.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 534904783 (510M)
# Saving to: ‘imagenet-vgg-verydeep-19.mat’
#
# imagenet-vgg-veryde 100%[===================>] 510.12M  29.9MB/s    in 17s
#
# 2021-05-11 02:20:53 (29.5 MB/s) - ‘imagenet-vgg-verydeep-19.mat’ saved [534904783/534904783]

# %%
# 파일 이동
# !mv imagenet-vgg-verydeep-19.mat neural-style/
print('files move complete!!')
# Out:
# files move complete!!

# %%
# %cd neural-style
# !pip install -r requirements.txt
# Out:
# /content/neural-style
# ...
#      |████████████████████████████████| 31.2MB 92kB/s
# ...
#      |████████████████████████████████| 411.0MB 42kB/s
# ...
#      |████████████████████████████████| 3.8MB 42.2MB/s
# ...
#      |████████████████████████████████| 51kB 8.1MB/s
# ...
#      |████████████████████████████████| 512kB 44.1MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp37-none-any.whl size=7540 sha256=2d5443cc37efa861fd8d777a8f9cc883a8148e5c5c0116be9109793c23ab4a4e
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow 2.4.1 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.4.1 has requirement tensorboard~=2.4, but you'll have tensorboard 1.15.0 which is incompatible.
# ERROR: tensorflow 2.4.1 has requirement tensorflow-estimator<2.5.0,>=2.4.0, but you'll have tensorflow-estimator 1.15.1 which is incompatible.
# ...

# %%
# !python neural_style.py --content <content file> --styles <style file> --output <output file>
# !python neural_style.py --content /content/gdrive/MyDrive/CV2/Style\ Transfer/bukchon.PNG --styles /content/gdrive/MyDrive/CV2/Style\ Transfer/image/RAIN-PRINCESS.jpg --output output_bukchon.png
# Out:
# WARNING:tensorflow:From /content/neural-style/vgg.py:9: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /content/neural-style/vgg.py:11: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-05-11 02:22:44.586812: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-05-11 02:22:44.591524: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2021-05-11 02:22:44.591706: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55aca3efca00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-05-11 02:22:44.591735: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# ...

# %%
# --preserve-colors : content file color 를 반영하여 style 을 만듬 

# !python neural_style.py --content /content/gdrive/MyDrive/CV2/Style\ Transfer/bukchon.PNG --styles /content/gdrive/MyDrive/CV2/Style\ Transfer/image/RAIN-PRINCESS.jpg --output output_bukchon1.png --preserve-colors

#!python neural_style.py --content /content/neural-style/examples/myface.jpg --styles /content/neural-style/examples/RAIN-PRINCESS.jpg --output myface_output1.jpg --preserve-colors
# Out:
# WARNING:tensorflow:From /content/neural-style/vgg.py:9: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /content/neural-style/vgg.py:11: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-05-11 02:26:59.324597: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-05-11 02:26:59.329302: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2021-05-11 02:26:59.329510: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55aa58152a00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-05-11 02:26:59.329540: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# ...
