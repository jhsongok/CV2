# %% [markdown]
# # 1. Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls -la "/content/gdrive/My Drive/darknet"
# Out:
# total 36
# drwx------ 2 root root 4096 May  9 00:41 apple_detection_dataset
# drwx------ 2 root root 4096 May  8 05:33 backup
# drwx------ 2 root root 4096 May  3 15:02 bin
# drwx------ 2 root root 4096 May  6 14:33 cfg
# drwx------ 2 root root 4096 May  3 14:38 cuDNN
# drwx------ 2 root root 4096 May  9 10:49 custom
# drwx------ 2 root root 4096 May  6 14:33 data
# drwx------ 2 root root 4096 May 13 16:19 FruitCustom_Yolo4_backup
# drwx------ 2 root root 4096 May  3 15:07 weights

# %%
# Colab에 cuDNN 이 설치되어 있는지 확인
# !ls -la /usr/local/cuda/include/cudnn.h
# Out:
# ls: cannot access '/usr/local/cuda/include/cudnn.h': No such file or directory

# %% [markdown]
# # 2. Install CUDA related modules, cuDNN
#
# Unzip the cuDNN from Google Drive to Colab /usr/local/cuda folder

# %%
# Colab에 설치되어 있는 CUDA 버전에 맞는 cuDNN을 구글 드라이브로부터 압축 해제해서 /usr/local/으로 복사
# !tar -xzvf gdrive/My\ Drive/darknet/cuDNN/cudnn-11.0-linux-x64-v8.0.5.39.tgz -C /usr/local/
# !chmod a+r /usr/local/cuda/include/cudnn.h

# cuDNN 버전 확인
# !cat /usr/local/cuda/include/cudnn.h | grep CUDNN_MAJOR -A 2
# Out:
# cuda/include/cudnn.h
# cuda/include/cudnn_adv_infer.h
# cuda/include/cudnn_adv_train.h
# cuda/include/cudnn_backend.h
# cuda/include/cudnn_cnn_infer.h
# cuda/include/cudnn_cnn_train.h
# cuda/include/cudnn_ops_infer.h
# cuda/include/cudnn_ops_train.h
# cuda/include/cudnn_version.h
# cuda/NVIDIA_SLA_cuDNN_Support.txt
# cuda/lib64/libcudnn.so
# cuda/lib64/libcudnn.so.8
# cuda/lib64/libcudnn.so.8.0.5
# cuda/lib64/libcudnn_adv_infer.so
# cuda/lib64/libcudnn_adv_infer.so.8
# cuda/lib64/libcudnn_adv_infer.so.8.0.5
# cuda/lib64/libcudnn_adv_train.so
# cuda/lib64/libcudnn_adv_train.so.8
# cuda/lib64/libcudnn_adv_train.so.8.0.5
# cuda/lib64/libcudnn_cnn_infer.so
# cuda/lib64/libcudnn_cnn_infer.so.8
# cuda/lib64/libcudnn_cnn_infer.so.8.0.5
# cuda/lib64/libcudnn_cnn_train.so
# cuda/lib64/libcudnn_cnn_train.so.8
# cuda/lib64/libcudnn_cnn_train.so.8.0.5
# cuda/lib64/libcudnn_ops_infer.so
# cuda/lib64/libcudnn_ops_infer.so.8
# cuda/lib64/libcudnn_ops_infer.so.8.0.5
# ...

# %% [markdown]
# ## 3. Load DarkNet

# %%
# Colab VM에 darknet 폴더를 만든다.
import os
if not os.path.exists('darknet'):
    os.makedirs('darknet')
# %cd darknet
# %ls
# Out:
# /content/darknet

# %%
# 1.Verify that the compiled Darknet exists in the Google drive.
# !ls -la '/content/gdrive/My Drive/darknet/bin/darknet'

# 2.Copy the Darknet compiled version to the VM
# !cp /content/gdrive/My\ Drive/darknet/bin/darknet ./darknet

# 3.Set execution permissions
# !chmod +x ./darknet
# Out:
# -rw------- 1 root root 6516872 May 11 06:18 '/content/gdrive/My Drive/darknet/bin/darknet'

# %% [markdown]
# # 4. Test Yolo

# %%
# 내 구글 드라이브에 있는 필요한 파일을 VM으로 가져온다.
# !cp -r '/content/gdrive/My Drive/darknet/weights' .
# !cp -r '/content/gdrive/My Drive/darknet/cfg' .
# !cp -ar '/content/gdrive/My Drive/darknet/data' .
# !cp -r '/content/gdrive/My Drive/darknet/custom' .

# VM의 darknet 폴더에 backup 폴더를 만든다.
if not os.path.exists('./backup'):
    os.makedirs('./backup')

# %ls
# Out:
# backup/  cfg/  custom/  darknet*  data/  weights/

# %%
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()
  
  
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)
def download(path):
  from google.colab import files
  files.download(path)

# %%
# !./darknet detect cfg/yolov3.cfg weights/yolov3.weights custom/fruit02.jpg
imShow('predictions.jpg')
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 8.0.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 700, cudnn_half = 1, GPU: Tesla V100-SXM2-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %% [markdown]
# # 5. Custom Yolo Training and Test

# %%
# Custom Yolo Training
# !./darknet detector train custom/custom_data.data custom/custom-train-yolo3.cfg weights/darknet53.conv.74 -dont_show -map
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.924950), count: 4, class_loss = 0.000000, iou_loss = 0.048347, total_loss = 0.048347
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 962674, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.964394), count: 5, class_loss = 0.000000, iou_loss = 0.010133, total_loss = 0.010133
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.829328), count: 1, class_loss = 0.004938, iou_loss = 0.029354, total_loss = 0.034292
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 962680, rewritten_bbox = 0.000000 %
# ...

# %%
# 학습된 weight 파일 성능 측정(mAP)
# !./darknet detector map custom/custom_data.data custom/custom-train-yolo3.cfg backup/custom-train-yolo3_last.weights
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 8.0.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 700, cudnn_half = 1, GPU: Tesla V100-SXM2-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %%
# !./darknet detector map custom/custom_data.data custom/custom-train-yolo3.cfg backup/custom-train-yolo3_final.weights
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 8.0.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 700, cudnn_half = 1, GPU: Tesla V100-SXM2-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %%
# !./darknet detector map custom/custom_data.data custom/custom-train-yolo3.cfg backup/custom-train-yolo3_4000.weights
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 8.0.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 700, cudnn_half = 1, GPU: Tesla V100-SXM2-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %%
# !./darknet detector map custom/custom_data.data custom/custom-train-yolo3.cfg backup/custom-train-yolo3_3000.weights
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 8.0.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 700, cudnn_half = 1, GPU: Tesla V100-SXM2-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %%
# !./darknet detector map custom/custom_data.data custom/custom-train-yolo3.cfg backup/custom-train-yolo3_2000.weights
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 8.0.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 700, cudnn_half = 1, GPU: Tesla V100-SXM2-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %%
# !./darknet detector map custom/custom_data.data custom/custom-train-yolo3.cfg backup/custom-train-yolo3_1000.weights
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 8.0.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 700, cudnn_half = 1, GPU: Tesla V100-SXM2-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %%
# 성능(mAP)이 가장 좋은 weight만 남겨 두고 구글 드라이브에 복사해 둔다.
if os.path.exists('./backup'):
    # !cp -r ./backup "/content/gdrive/My Drive/darknet/FruitCustom_Yolo3_backup"  

if not os.path.exists('./backup'):
    os.makedirs('./backup')
    # !cp -r "/content/gdrive/My Drive/darknet/FruitCustom_Yolo3_backup/custom-train-yolo3_final.weights" ./backup

# %%
# !ls -al ./backup
# Out:
# total 2165192
# drwxr-xr-x 2 root root      4096 May 14 04:11 .
# drwxr-xr-x 7 root root      4096 May 14 01:46 ..
# -rw-r--r-- 1 root root 246348468 May 14 02:08 custom-train-yolo3_1000.weights
# -rw-r--r-- 1 root root 246348468 May 14 02:33 custom-train-yolo3_2000.weights
# -rw-r--r-- 1 root root 246348468 May 14 02:56 custom-train-yolo3_3000.weights
# -rw-r--r-- 1 root root 246348468 May 14 03:21 custom-train-yolo3_4000.weights
# -rw-r--r-- 1 root root 246348468 May 14 03:45 custom-train-yolo3_5000.weights
# -rw-r--r-- 1 root root 246348468 May 14 04:11 custom-train-yolo3_6000.weights
# -rw-r--r-- 1 root root 246348468 May 14 02:11 custom-train-yolo3_best.weights
# -rw-r--r-- 1 root root 246348468 May 14 04:11 custom-train-yolo3_final.weights
# -rw-r--r-- 1 root root 246348468 May 14 04:11 custom-train-yolo3_last.weights

# %%
# Custom Yolo Test
# !./darknet detector test custom/custom_data.data custom/custom-test-yolo3.cfg backup/custom-train-yolo3_final.weights custom/fruit04.jpg -dont-show

imShow('predictions.jpg')
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 8.0.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 700, cudnn_half = 1, GPU: Tesla V100-SXM2-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...
