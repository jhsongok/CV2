# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import cv2
from google.colab.patches import cv2_imshow

face_cascade = cv2.CascadeClassifier('/content/gdrive/MyDrive/CV/Face Detection/data/haarcascades/haarcascade_frontalface_default.xml')

src = cv2.imread('/content/gdrive/MyDrive/CV/Face Detection/data/image/face_02.jpg')
src_gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)

faces = face_cascade.detectMultiScale(src_gray)

ratio = 0.05

for x, y, w, h in faces:
    small = cv2.resize(src[y: y + h, x: x + w], None, fx=ratio, fy=ratio, interpolation=cv2.INTER_NEAREST)
    src[y: y + h, x: x + w] = cv2.resize(small, (w, h), interpolation=cv2.INTER_NEAREST)

cv2_imshow(src)
# Out:
# <PIL.Image.Image image mode=RGB size=600x434 at 0x7FE073134190>

# %%
import cv2
from google.colab.patches import cv2_imshow

face_cascade = cv2.CascadeClassifier('/content/gdrive/MyDrive/CV/Face Detection/data/haarcascades/haarcascade_frontalface_default.xml')

src = cv2.imread('/content/gdrive/MyDrive/CV/Face Detection/data/image/face_02.jpg')
src_gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)

faces = face_cascade.detectMultiScale(src_gray)

ratio = 0.1

for x, y, w, h in faces:
    small = cv2.resize(src[y: y + h, x: x + w], None, fx=ratio, fy=ratio, interpolation=cv2.INTER_NEAREST)
    src[y: y + h, x: x + w] = cv2.resize(small, (w, h), interpolation=cv2.INTER_NEAREST)

cv2_imshow(src)
# Out:
# <PIL.Image.Image image mode=RGB size=600x434 at 0x7FE073133090>
